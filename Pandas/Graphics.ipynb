# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(200, size=(50,4)), columns=['a','b','c','d'])

# %%
df.head()
# Out:
#      a    b    c    d
# 0   19   18  171    8
# 1  162   23  125    6
# 2  181  186  108   27
# 3   11  141  166   46
# 4  133    4   10  153

# %%
df['a'].plot.hist()

# %%
df['b'].hist()

# %%
df.plot.kde()

# %%
df.plot.line(x='a', y='b')

# %%
df.plot.barh()

# %%
df.plot.box()
