# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data.txt')

# %%
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
df.describe()
# Out:
#        Account Length    Area Code  VMail Message     Day Mins    Day Calls  \
# count     3333.000000  3333.000000    3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418       8.099010   179.775098   100.435644
# std         39.822106    42.371290      13.688365    54.467389    20.069084
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000   143.700000    87.000000
# 50%        101.000000   415.000000       0.000000   179.400000   101.000000
# 75%        127.000000   510.000000      20.000000   216.400000   114.000000
# max        243.000000   510.000000      51.000000   350.800000   165.000000
#
#         Day Charge     Eve Mins    Eve Calls   Eve Charge   Night Mins  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean     30.562307   200.980348   100.114311    17.083540   200.872037
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'Int'l Plan',
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
#        'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
#        'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge',
#        'CustServ Calls', 'Churn?'],
#       dtype='object')

# %%
df_day = df[['Day Mins', 'Day Calls']]
df_day.head()
# Out:
#    Day Mins  Day Calls
# 0     265.1        110
# 1     161.6        123
# 2     243.4        114
# 3     299.4         71
# 4     166.7        113

# %%
df_day.describe()
# Out:
#           Day Mins    Day Calls
# count  3333.000000  3333.000000
# mean    179.775098   100.435644
# std      54.467389    20.069084
# min       0.000000     0.000000
# 25%     143.700000    87.000000
# 50%     179.400000   101.000000
# 75%     216.400000   114.000000
# max     350.800000   165.000000

# %%
plt.plot(df_day['Day Calls'], df_day['Day Mins'], 'x')
plt.xlabel('Day Calls')
plt.ylabel('Day Mins')
plt.show()

# %%
df_day = df_day[(df_day['Day Mins'] < 179.775098) & (df_day['Day Calls'] < 100.435644)]

# %%
plt.plot(df_day['Day Mins'], df_day['Day Calls'],  'x')

# %%
df_day.describe()
# Out:
#          Day Mins   Day Calls
# count  840.000000  840.000000
# mean   136.677619   84.605952
# std     32.094502   12.624803
# min      0.000000    0.000000
# 25%    117.600000   78.000000
# 50%    143.200000   88.000000
# 75%    161.425000   94.000000
# max    179.400000  100.000000

# %%
df_day = df_day[(df_day['Day Mins'] < 136.677619) & (df_day['Day Calls'] < 84.605952)]
plt.plot(df_day['Day Mins'], df_day['Day Calls'],  'x')

# %%
df_day.describe()
# Out:
#         Day Mins   Day Calls
# count  145.00000  145.000000
# mean   106.87931   71.151724
# std     27.85284   12.728648
# min      0.00000    0.000000
# 25%     96.60000   66.000000
# 50%    115.00000   74.000000
# 75%    128.30000   80.000000
# max    136.10000   84.000000

# %%
df_day = df_day[(df_day['Day Mins'] < 106.87931) & (df_day['Day Calls'] < 71.151724)]
plt.plot(df_day['Day Mins'], df_day['Day Calls'],  'x')
