# %%
import pandas as pd

# %%
data_url = 'https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses'

# %%
data=pd.read_html(data_url)

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
#                                             0  \
# 0                       Estado(forma oficial)
# 1            República Islámica de Afganistán
# 2                        República de Albania
# 3               República Federal de Alemania
# 4                       Principado de Andorra
# 5                         República de Angola
# 6                           Antigua y Barbuda
# 7                     Reino de Arabia Saudita
# 8    República Argelina Democrática y Popular
# 9                         República Argentina
# 10                       República de Armenia
# 11                  Mancomunidad de Australia
# 12                       República de Austria
# 13                    República de Azerbaiyán
# 14                Mancomunidad de las Bahamas
# 15             República Popular de Bangladés
# 16                                   Barbados
# 17                            Reino de Baréin
# 18                           Reino de Bélgica
# ...

# %%
df = pd.DataFrame(data[0])

# %%
df.head(10)
# Out:
#                                           0                              1  \
# 0                     Estado(forma oficial)                   Nombre común
# 1          República Islámica de Afganistán                     Afganistán
# 2                      República de Albania                        Albania
# 3             República Federal de Alemania                       Alemania
# 4                     Principado de Andorra                        Andorra
# 5                       República de Angola                         Angola
# 6                         Antigua y Barbuda              Antigua y Barbuda
# 7                   Reino de Arabia Saudita  Arabia Saudí / Arabia Saudita
# 8  República Argelina Democrática y Popular                        Argelia
# 9                       República Argentina                      Argentina
#
#                                      2                 3           4  \
# 0                    Forma de gobierno       Capital(es)  Continente
# ...

# %%
df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
df.dropna()
# Out:
#                        0             1                  2            3  \
# 0  Estado(forma oficial)  Nombre común  Forma de gobierno  Capital(es)
#
#             4            5          6      7          8
# 0  Continente  Estatus ONU  Soberanía  Notas  Ubicación
