# %%
import pandas as pd
import matplotlib as mp

# %%
filename = 'data.txt'

# %%
data = pd.read_csv(filename)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
df.tail(3)
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 3330              0     180.8        109       30.74   ...           58
# 3331              0     213.8        105       36.35   ...           84
# 3332             25     234.4        113       39.85   ...           82
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 3330       24.55       191.9           91          8.64       14.1
# 3331       13.57       139.2          137          6.26        5.0
# 3332       22.60       241.4           77         10.86       13.7
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 3330           6         3.81               2  False.
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'Int'l Plan',
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
#        'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
#        'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge',
#        'CustServ Calls', 'Churn?'],
#       dtype='object')

# %%
features = ['State', 'Phone', 'Day Mins', 'Eve Mins', 'Night Mins']

# %%
df[features].head()
# Out:
#   State     Phone  Day Mins  Eve Mins  Night Mins
# 0    KS  382-4657     265.1     197.4       244.7
# 1    OH  371-7191     161.6     195.5       254.4
# 2    NJ  358-1921     243.4     121.2       162.6
# 3    OH  375-9999     299.4      61.9       196.9
# 4    OK  330-6626     166.7     148.3       186.9

# %%
features_df = df[features]
features_df.head()
# Out:
#   State     Phone  Day Mins  Eve Mins  Night Mins
# 0    KS  382-4657     265.1     197.4       244.7
# 1    OH  371-7191     161.6     195.5       254.4
# 2    NJ  358-1921     243.4     121.2       162.6
# 3    OH  375-9999     299.4      61.9       196.9
# 4    OK  330-6626     166.7     148.3       186.9

# %%
features_df[features_df['Day Mins'] < 100].head()
# Out:
#    State     Phone  Day Mins  Eve Mins  Night Mins
# 21    CO  393-7984      62.4     169.9       209.6
# 24    VA  343-4696      81.1     245.2       237.0
# 30    IL  416-8428      84.8     136.7       250.5
# 43    ID  390-7274      85.8     165.3       178.5
# 77    NY  360-1171      61.6      77.1       173.0

# %%
features_df[features_df['State']=='CO'].head()
# Out:
#     State     Phone  Day Mins  Eve Mins  Night Mins
# 21     CO  393-7984      62.4     169.9       209.6
# 56     CO  340-5121     126.9     180.0       140.8
# 57     CO  370-7574     198.4      75.3       181.2
# 82     CO  419-2637     165.6     136.1       175.7
# 108    CO  371-4306     148.6     131.1       219.4

# %%
df.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'Int'l Plan',
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
#        'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
#        'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge',
#        'CustServ Calls', 'Churn?'],
#       dtype='object')

# %%
df[['Day Calls','Day Mins']].head()
# Out:
#    Day Calls  Day Mins
# 0        110     265.1
# 1        123     161.6
# 2        114     243.4
# 3         71     299.4
# 4        113     166.7

# %%
df[['Day Calls','Day Mins']].plot()
